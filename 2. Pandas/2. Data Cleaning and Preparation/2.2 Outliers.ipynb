# %% [markdown]
# # Outliers
# This notebook is intended to provide various ways to detect the outliers.
# ___
# If you are coming from the previous notebook (2. Transforming data) then I want to clarify something first.
# - This notebook can be updated frequenty as far as I discover new ways to detect and remove outliers (from this book)
# - First example (very first) is just so simple - and being an outlier doesn't end there

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %% [markdown]
# #

# %% [markdown]
# ## Basic Outlier

# %%
df = DataFrame(np.random.randn(100, 4))
df.describe()
# Out:
#                 0           1           2           3
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.173463   -0.015103   -0.231392    0.046166
# std      1.068750    1.067518    1.093479    1.005034
# min     -2.196299   -2.582840   -3.713380   -2.788125
# 25%     -0.504283   -0.740742   -1.150561   -0.716982
# 50%      0.298811   -0.036227   -0.054689    0.002347
# 75%      0.883417    0.757753    0.511272    0.890928
# max      3.218513    2.789202    2.367302    2.559666

# %% [markdown]
# Now, that we have a data, but We see that ther are some values getting more than 2...
# As a dummy example, the values can't get above 2 or below -2.
#
# So...

# %% [markdown]
# ### 1. Check

# %%
df[np.abs(df[0]) > 2]
# Out:
#            0         1         2         3
# 4   3.218513 -0.688628  0.586290  0.373257
# 13  2.023627  0.695923 -0.520284  0.306238
# 46 -2.196299  1.640499 -1.075587 -0.069167
# 53 -2.084976  0.703409 -1.543034  0.555975
# 75  3.176328  0.236336 -1.808515 -0.576179

# %%
df[np.abs(df[1]) > 2]
# Out:
#            0         1         2         3
# 35  1.970374  2.789202 -3.713380  1.903543
# 45 -0.653400 -2.183555  0.769060 -0.763131
# 76 -0.508287 -2.030815 -1.161269 -1.711957
# 79  0.617072 -2.582840 -0.949572  0.162737
# 94  1.269597 -2.528789 -0.413810  0.581075

# %%
df[np.abs(df[2]) > 2]
# Out:
#            0         1         2         3
# 3   0.683447  1.386483 -2.061696 -0.186593
# 35  1.970374  2.789202 -3.713380  1.903543
# 41  1.900607 -1.561373  2.367302  1.680957
# 60 -1.068619 -1.823509 -2.006502  0.923302
# 62 -0.752614  0.739068 -2.485644 -1.259811

# %%
df[np.abs(df[3]) > 2]
# Out:
#            0         1         2         3
# 8  -0.810934  0.842951 -1.732263  2.559666
# 28  1.297917  1.020595  0.411189 -2.788125
# 72  0.269266 -0.747677 -1.827473  2.331064

# %% [markdown]
# ### 2. Step 1 was verbose.
# Get all rows at once.

# %%
# So these are the OUTLYING values
# The code below is based on a condition. Cool - I have made a gist on it. Check it here: https://gist.github.com/AayushSameerShah/330d000dfa9b245646391d1c5f167147

df[(np.abs(df) > 2).any(1)].style.applymap(lambda x: "background: yellow" if np.abs(x) > 2 else "")
# Out:
# <style  type="text/css" >
# #T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row0_col2,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row1_col0,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row2_col3,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row3_col0,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row4_col3,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row5_col1,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row5_col2,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row6_col2,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row7_col1,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row8_col0,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row9_col0,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row10_col2,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row11_col2,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row12_col3,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row13_col0,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row14_col1,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row15_col1,#T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row16_col1{
#             background:  yellow;
#         }</style><table id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64level0_row0" class="row_heading level0 row0" >3</th>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row0_col0" class="data row0 col0" >0.683447</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row0_col1" class="data row0 col1" >1.386483</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row0_col2" class="data row0 col2" >-2.061696</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row0_col3" class="data row0 col3" >-0.186593</td>
#             </tr>
#             <tr>
#                         <th id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64level0_row1" class="row_heading level0 row1" >4</th>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row1_col0" class="data row1 col0" >3.218513</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row1_col1" class="data row1 col1" >-0.688628</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row1_col2" class="data row1 col2" >0.586290</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row1_col3" class="data row1 col3" >0.373257</td>
#             </tr>
#             <tr>
#                         <th id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64level0_row2" class="row_heading level0 row2" >8</th>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row2_col0" class="data row2 col0" >-0.810934</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row2_col1" class="data row2 col1" >0.842951</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row2_col2" class="data row2 col2" >-1.732263</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row2_col3" class="data row2 col3" >2.559666</td>
#             </tr>
#             <tr>
#                         <th id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64level0_row3" class="row_heading level0 row3" >13</th>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row3_col0" class="data row3 col0" >2.023627</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row3_col1" class="data row3 col1" >0.695923</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row3_col2" class="data row3 col2" >-0.520284</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row3_col3" class="data row3 col3" >0.306238</td>
#             </tr>
#             <tr>
#                         <th id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64level0_row4" class="row_heading level0 row4" >28</th>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row4_col0" class="data row4 col0" >1.297917</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row4_col1" class="data row4 col1" >1.020595</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row4_col2" class="data row4 col2" >0.411189</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row4_col3" class="data row4 col3" >-2.788125</td>
#             </tr>
#             <tr>
#                         <th id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64level0_row5" class="row_heading level0 row5" >35</th>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row5_col0" class="data row5 col0" >1.970374</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row5_col1" class="data row5 col1" >2.789202</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row5_col2" class="data row5 col2" >-3.713380</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row5_col3" class="data row5 col3" >1.903543</td>
#             </tr>
#             <tr>
#                         <th id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64level0_row6" class="row_heading level0 row6" >41</th>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row6_col0" class="data row6 col0" >1.900607</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row6_col1" class="data row6 col1" >-1.561373</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row6_col2" class="data row6 col2" >2.367302</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row6_col3" class="data row6 col3" >1.680957</td>
#             </tr>
#             <tr>
#                         <th id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64level0_row7" class="row_heading level0 row7" >45</th>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row7_col0" class="data row7 col0" >-0.653400</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row7_col1" class="data row7 col1" >-2.183555</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row7_col2" class="data row7 col2" >0.769060</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row7_col3" class="data row7 col3" >-0.763131</td>
#             </tr>
#             <tr>
#                         <th id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64level0_row8" class="row_heading level0 row8" >46</th>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row8_col0" class="data row8 col0" >-2.196299</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row8_col1" class="data row8 col1" >1.640499</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row8_col2" class="data row8 col2" >-1.075587</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row8_col3" class="data row8 col3" >-0.069167</td>
#             </tr>
#             <tr>
#                         <th id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64level0_row9" class="row_heading level0 row9" >53</th>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row9_col0" class="data row9 col0" >-2.084976</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row9_col1" class="data row9 col1" >0.703409</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row9_col2" class="data row9 col2" >-1.543034</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row9_col3" class="data row9 col3" >0.555975</td>
#             </tr>
#             <tr>
#                         <th id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64level0_row10" class="row_heading level0 row10" >60</th>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa7974e64row10_col0" class="data row10 col0" >-1.068619</td>
#                         <td id="T_c249ab35_bed1_11eb_bbe3_3c6aa797

# %% [markdown]
# ### 3. Fix em

# %%
df[np.abs(df) > 2] = np.sign(df) * 2
# Out:
#            0   1         2   3
# 0        NaN NaN       NaN NaN
# 1        NaN NaN       NaN NaN
# 2        NaN NaN       NaN NaN
# 3        NaN NaN -2.061696 NaN
# 4   3.218513 NaN       NaN NaN
# ..       ...  ..       ...  ..
# 95       NaN NaN       NaN NaN
# 96       NaN NaN       NaN NaN
# 97       NaN NaN       NaN NaN
# 98       NaN NaN       NaN NaN
# 99       NaN NaN       NaN NaN
#
# [100 rows x 4 columns]

# %% [markdown]
# The syntax above is a little weird. As the whole DF is returned, but the assignment is only done to the NON NAN values. But its fine.
#
# Done, for this simple outlier.
